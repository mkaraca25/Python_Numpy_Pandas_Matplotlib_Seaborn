# %%
n=int(input ("Faktöriyeli hesaplanacak sayıyı giriniz:"))
f = 1
for sayac in range (1,n+1):
    f *=sayac
print("{0} sayısının faktöriyeli = {1} dir ".format(n,f))

# %%
import matplotlib.pyplot as plt
m=[x**3 for x in range(1,11)]
plt.plot(m)
print(m)

# %%
import matplotlib.pyplot as plt
from math import sin,cos,tan
import numpy as np
ax = plt.subplot(2,1,2)
x = np.linspace(-50,50,10)
y =plt.plot(x,np.sin(x),'--r')
z= plt.plot(x,np.cos(x),'-b')
t= plt.plot(x,np.tan(x),'-b^')
leg = plt.legend(loc='best', ncol=2, mode="expand", shadow=True, fancybox=True)
plt.title("9200004 Melik KARACA")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: np.exp(-x**2)*np.sin(x)
x = np.linspace(-np.pi, np.pi, 101)
plt.plot(x, f(x), 'r--')          #plt.plot(x, f(x), c='red', ls='-')
plt.title('Bir Grafik')
plt.xlabel('x')
plt.ylabel('y=f(x)')
plt.axis([-np.pi, np.pi, -1, 1]) #[xmin, xmax, ymin, ymax]
plt.show()

# %%
def test(x=3,y=4):
    return x+y,x-y
x,y=test(y=2,x=1)
print(x,y)

# %%
y=0
for i in range(0,10,2):
    y+=i
print(y)

# %%
sayac=0
for i in range(10):
    for j in range(i):
        # %%print(i*j)
        sayac+=1
print(sayac)

# %%
lst=[[[1,2],[3,4]],[[5,6],[7,8]],
    [[9,6],[15,11]],[[22,6],[17,7]]]
print(lst[2][1][0])

# %%
sayi=6
while sayi>0:
    sayi-=3
    print(sayi,end=' ')

# %%
x=((1,2),(3,4,5),
  (5,6,5,9),(10,11,12),
   (20,30,40,50,60))
print(len(x),len(x[4]))

# %%
m=[[x,x+1,x+2] for x in range(0,3)]
print(m)

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
x=np.linspace(1,10,50)
y1=np.sin(x)
y2=np.cos(x)
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend(['y1=sin(x)', 'y2=cos(x)'])
plt.xlabel('X')
plt.ylabel('y1=sin(x)-y2=cos(x)')
plt.title('y1=sin(x)-y2=cos(x) GRAFİKLERİ')
plt.grid(b=True, linestyle='-' ,color='grey')
ax=plt.axes()
ax.set_facecolor("darkgrey")
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]
plt.figure(figsize=(9, 3))
plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)
plt.figure()
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')
plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)
plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
ax = plt.subplot()
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)
plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
        arrowprops=dict(facecolor='black', shrink=0.05),)
plt.ylim(-2, 2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# Fixing random state for reproducibility
np.random.seed(19680801)
# make up some data in the open interval (0, 1)
y = np.random.normal(loc=0.5, scale=0.4, size=1000)
y = y[(y > 0) & (y < 1)]
y.sort()
x = np.arange(len(y))
# plot with various axes scales
plt.figure()
# linear
plt.subplot(221)
plt.plot(x, y)
plt.yscale('linear')
plt.title('linear')
plt.grid(True)
# log
plt.subplot(222)
plt.plot(x, y)
plt.yscale('log')
plt.title('log')
plt.grid(True)
# symmetric log
plt.subplot(223)
plt.plot(x, y - y.mean())
plt.yscale('symlog', linthresh=0.01)
plt.title('symlog')
plt.grid(True)
# logit
plt.subplot(224)
plt.plot(x, y)
plt.yscale('logit')
plt.title('logit')
plt.grid(True)
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
wspace=0.35)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(19680801)
data = np.random.randn(2, 100)
fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])
plt.show()

# %%
fig = plt.figure()
fig.subplots_adjust(top=0.8)
ax1 = fig.add_subplot(211)
ax1.set_ylabel('volts')
ax1.set_title('a sine wave')
t = np.arange(0.0, 1.0, 0.01)
s = np.sin(2*np.pi*t)
line, = ax1.plot(t, s, color='blue', lw=2)
# Fixing random state for reproducibility
np.random.seed(19680801)
ax2 = fig.add_axes([0.15, 0.1, 0.7, 0.3])
n, bins, patches = ax2.hist(np.random.randn(1000), 50,
facecolor='yellow', edgecolor='yellow')
ax2.set_xlabel('time (s)')
plt.show()

# %%
# from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot([3, 2, 1], marker='o', label='Line 1')
line2, = plt.plot([1, 2, 3], marker='o', label='Line 2')
plt.legend(handler_map={line1: HandlerLine2D(numpoints=4)})
#line1, = plt.plot([1, 2, 3], label="Line 1", linestyle='--',linewidth=2.5)
#line2, = plt.plot([3, 2, 1], label="Line 2", linewidth=5)
# Create a legend for the first line.
first_legend = plt.legend(handles=[line1], loc='upper right')
# Add the legend manually to the current Axes.
plt.gca().add_artist(first_legend)
# Create another legend for the second line.
plt.legend(handles=[line2], loc='lower right')
plt.show()

# %%
from numpy.random import randn
z = randn(10)
red_dot, = plt.plot(z, "ro", markersize=15)
# Put a white cross over some of the data.
white_cross, = plt.plot(z[:5], "w+", markeredgewidth=3, markersize=15)
plt.legend([red_dot, (red_dot, white_cross)], ["Attr A", "Attr A+B"])

# %%
from matplotlib.legend_handler import HandlerLine2D, HandlerTuple
p1, = plt.plot([1, 2.5, 3], 'r-d')
p2, = plt.plot([3, 2, 1], 'k-o')
l = plt.legend([(p1, p2)], ['Two keys'], numpoints=4,
handler_map={tuple: HandlerTuple(ndivide=None)})

# %%
import matplotlib.patches as mpatches
from matplotlib.legend_handler import HandlerPatch
class HandlerEllipse(HandlerPatch):
    def create_artists(self, legend, orig_handle,xdescent, ydescent, width, height, fontsize, trans):
        center = 0.5 * width - 0.5 * xdescent, 0.5 * height - 0.5 * ydescent
        p = mpatches.Ellipse(xy=center, width=width + xdescent,
        height=height + ydescent)
        self.update_prop(p, orig_handle, legend)
        p.set_transform(trans)
        return [p]
c = mpatches.Circle((0.5, 0.5), 0.25, facecolor="green",edgecolor="red", linewidth=3)
plt.gca().add_patch(c)
plt.legend([c], ["An ellipse, not a rectangle"],
        handler_map={mpatches.Circle: HandlerEllipse()})

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.gridspec as gridspec
import numpy as np
arr = np.arange(100).reshape((10, 10))
norm = mcolors.Normalize(vmin=0., vmax=100.)
# see note above: this makes all pcolormesh calls consistent:
pc_kwargs = {'rasterized': True, 'cmap': 'viridis', 'norm': norm}
fig, ax = plt.subplots(figsize=(4, 4), constrained_layout=True)
im = ax.pcolormesh(arr, **pc_kwargs)
fig.colorbar(im, ax=ax, shrink=0.6)

# %%
def example_plot(ax, fontsize=12, hide_labels=False):
        ax.plot([1, 2])
        ax.locator_params(nbins=3)
        if hide_labels:
            ax.set_xticklabels([])
            ax.set_yticklabels([])
        else:
            ax.set_xlabel('x-label', fontsize=fontsize)
            ax.set_ylabel('y-label', fontsize=fontsize)
            ax.set_title('Title', fontsize=fontsize)
plt.rcParams['figure.constrained_layout.use'] = True 
fig, axs = plt.subplots(2, 2, figsize=(4, 4))
for ax in axs.flat:
    example_plot(ax)

# %% [markdown]
# ## Matplotlib Kutuphanesi

# %%
#interaktif mod
#%matplotlib notebook
#statik mod
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np
veri=np.arange(10)
print(plt.plot(veri))
plt.title('Grafik baslik')
# Out:
# ...
# Text(0.5, 1.0, 'Grafik baslik')

# %%
x=[1,2,3,4]
y=[1,4,9,16]
plt.plot(x,y,'r-*')

# %%
d=np.arange(0.,5.,0.2)
plt.plot(d,d,"r--",d,d**2,"bs",d,d**3,"g^")
#.pdf olarak pc kaydetme
plt.savefig("grafigim.pdf",dpi=500,bbox_inches="tight")

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
fig=plt.figure()
x1=fig.add_subplot(2,2,1)
data=np.random.randn(50).cumsum()
plt.plot(data,"k--")
x2=fig.add_subplot(2,2,2)
plt.plot(data,"r-")
x3=fig.add_subplot(2,2,3)
plt.plot(data,"b.")
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
x=[1,2,3,4,5]
y=[10,11,12,13,14]
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
#ax.plot(x,y,linestyle="--",color="b")
plt.plot(data,"ko--")
ax.set_xticks([10,20,30,40,50,60]) #x eksenini değiştirme
ax.set_xticklabels(["on","yirmi","otuz","kırk","elli","altmış"],rotation=30,fontsize="small")
ax.set_title("Grafigim")
ax.set_xlabel(" X degerler")
ax.set_ylabel(" Y degerler")
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, ' Y degerler')

# %%
x=[1,2,3,4,5]
y=[10,11,12,13,14]
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
#ax.plot(x,y,linestyle="--",color="b")
plt.plot(data,"ko--")
ozellik={"title": "Grafik",
        "xlabel": "adimlar",
        "ylabel":"sayilar"}
ax.set(**ozellik)
# Out:
# <img src="data:image/png;base64,..." width="432">
# [Text(0, 0.5, 'sayilar'), Text(0.5, 0, 'adimlar'), Text(0.5, 1.0, 'Grafik')]

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
veri1=np.random.randn(1000).cumsum()
veri2=np.random.randn(1000).cumsum()
veri3=np.random.randn(1000).cumsum()
ax.plot(veri1,"k",label="bir")
ax.plot(veri2,"b--",label="iki")
ax.plot(veri3,"r.",label="uc")
ax.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
import pandas as pd
veri=pd.read_csv("FB.csv",index_col=0,parse_dates=True)
veri.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-07-30  175.300003  175.300003  166.559998  171.059998  171.059998
# 2018-07-31  170.669998  174.240005  170.000000  172.580002  172.580002
# 2018-08-01  173.929993  175.080002  170.899994  171.649994  171.649994
# 2018-08-02  170.679993  176.789993  170.270004  176.369995  176.369995
# 2018-08-03  177.690002  178.850006  176.149994  177.779999  177.779999
#
#               Volume
# Date
# 2018-07-30  65280800
# 2018-07-31  40356500
# 2018-08-01  34042100
# 2018-08-02  32400000
# 2018-08-03  24763400

# %%
k_fiyat=veri["Close"]
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
k_fiyat.plot(ax=ax, style="k-")
plt.title("Facebook borsa kapanis fiyatlari")
k_fiyat.min()
# Out:
# <img src="data:image/png;base64,..." width="432">
# 124.059998

# %%
tarih="2018-12-24"
yazi="Minimum deger"
ax.annotate(yazi,xy=(tarih,125),xytext=(tarih,150),
           arrowprops=dict(facecolor="red"))
# Out:
# Text(2018-12-24, 150, 'Minimum deger')

# %%
plt.savefig("grafigim.png")
