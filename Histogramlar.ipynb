# %% [markdown]
# ## Histogramlar

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# %matplotlib inline
plt.style.use("fivethirtyeight")#grafik stili
#print(plt.style.available)#  diger grafik stilleri

# %%
veri=np.random.randn(1000)
bins=[-3,-2,-1,0,1,2,3]
ortanca=np.median(veri)
plt.axvline(ortanca,color="red")
plt.hist(veri,edgecolor="black",bins=bins)
plt.title("Histogramlar")
plt.xlabel("Degerler")
plt.ylabel("Frekanslar")
# Out:
# Text(0, 0.5, 'Frekanslar')

# %%
x1=np.random.normal(0,0.8,1000)
x2=np.random.normal(-3,2,1000)
x3=np.random.normal(2,1,1000)

# %%
plt.hist(x1,histtype="stepfilled",alpha=0.5)
plt.hist(x2,histtype="stepfilled",alpha=0.5)
plt.hist(x3,histtype="stepfilled",alpha=0.5)
# Out:
# (array([ 11.,  56., 110., 163., 211., 210., 153.,  62.,  16.,   8.]),
#  array([-0.77112963, -0.18994486,  0.3912399 ,  0.97242467,  1.55360944,
#          2.1347942 ,  2.71597897,  3.29716373,  3.8783485 ,  4.45953326,
#          5.04071803]),
#  <a list of 1 Patch objects>)

# %%
mean=[0,0]
cov=[[1,1],[1,2]]
x,y=np.random.multivariate_normal(mean,cov,1000).T
plt.hist2d(x,y,bins=30, cmap="Reds")
cb=plt.colorbar()
cb.set_label("Dikdörtgenlerin sayisi")

# %%
film=pd.read_csv("imdbratings.txt")

# %%
pd.read_csv("http://bit.ly/imdbratings")#internetten indirme
film.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
plt.style.use("ggplot")
bins=np.arange(70,250,10)
plt.xticks(bins)
plt.hist(film.duration, edgecolor="black",color="m",bins=bins)
plt.title("imdb deki filmlerin surelerinin histogramları")
plt.xlabel("Sureler")
plt.ylabel("Frekanslar")
# Out:
# Text(0, 0.5, 'Frekanslar')
