# %% [markdown]
#  ## Pandas da Veri Görsellestirme

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
plt.style.use("fivethirtyeight")

# %%
veri=pd.Series(np.random.randn(1000).cumsum())
veri.plot()

# %%
df=pd.DataFrame(np.random.randn(100,4),columns=list("ABCD"))
df=df.cumsum()
df.plot()

# %%
df.iloc[10].plot(kind="bar")

# %%
df.iloc[10].plot.bar()

# %%
vs=pd.DataFrame(np.random.randn(7,3),columns=list("ABC"))
vs.plot.bar()

# %%
vs.plot.bar(stacked=True)

# %%
iris=pd.read_csv("iris.txt",sep="\t")
iris.head()
iris.plot.hist(alpha=1,stacked=True,bins=25)

# %%
iris["Canak_yaprak_eni"].plot.hist(orientation="horizontal")

# %%
iris["Canak_yaprak_boyu"].diff().hist()

# %%
plt.style.use("seaborn-whitegrid")
iris.hist(color="blue",alpha=1,bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB218C1388>,
# ...
#       dtype=object)

# %%
iris.hist("Canak_yaprak_boyu",by="Turu")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB212FEA08>,
# ...
#       dtype=object)

# %%
iris.plot.box()

# %%
renk={"boxes":"Red","whiskers":"blue","medians":"black","caps":"green"}
iris.plot.box(color=renk)

# %%
iris.plot.box(vert=False)

# %%
iris.boxplot()

# %%
plt.style.use("ggplot")
iris.boxplot(by="Turu")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001FB2629BFC8>,
# ...
#       dtype=object)
