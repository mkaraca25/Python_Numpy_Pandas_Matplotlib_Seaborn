# %%
toplam=0
for i in range(1,100):
    toplam+=i/(i+1)
print("Toplam",toplam)
##CEVAP B
# Out:
# Toplam 94.81262248236033

# %%
for i in range(6,0,-1):
    for j in range(6+1,0,-1):
        print(j if j<=i else " ",end=" ")
    print()
#CEVAP B
# Out:
#   6 5 4 3 2 1
#     5 4 3 2 1
#       4 3 2 1
#         3 2 1
#           2 1
#             1

# %%
count=0
while count<100:
    #Point A
    #print("Welcome to Python!")
    count+=1
    #Point B
#Point C
print(count)
# Out:
# 100

# %%
def test(x=3,y=4):
    return x+y,x-y
x,y=test(y=2,x=1)
print(x,y)
# Out:
# 3 -1

# %%
count=0
while count<10:
    print("Erzurum teknik üniversitesi")
#CEVAP SONSUZ SAYIDA

# %%
#for count in range(1,10):
    #print("Merhaba dünya")
    #9 defa
#for count in range(0,10):
    #print("Merhaba dünya")
    #10 defa
#for count in range(1,11):
    #print("Merhaba dünya")
    #10 defa
#for count in range(1,12):
    #print("Merhaba dünya")
    #11 defa
#CEVAP BC

# %%
def test(sayi):
    return sayi
print(test(11))
# Out:
# 11

# %%
#x=1
#def test():
   # x=x+2
    #print(x)
#test()
#print(x)
#X tanımlanmadığından hata verir.

# %%
def test(param1,param2=[]):
    param2.append(param1)
    return param1+param2[-1]
test(1)
test(2)
t=test(3)
print(t)
# Out:
# 6

# %%
def nyaz(mesaj,n):
    while n>0:
        print(mesaj,end="")
        n-=1
nyaz("ETU",4)
# Out:
# ETUETUETUETU

# %%
listem=[1,2,3,4,5,6]
for i in range(1,6):
    listem[i-1]=listem[i]
for i in range(0,6):
    print(listem[i],end="")
# Out:
# 234566

# %%
sayi =6
while sayi>0:
    sayi-=3
    print(sayi,end="")
# Out:
# 30

# %%
def test():
    global x
    x=x+2
    print(x)
test()
print(x)
# Out:
# 3
# 3

# %%
x = 1
count = 0
while True:
    text = str(x)
    for i in text:
        if i == "1":
            count += 1
            
    if count == 689:
        break
    
    x += 1
    
print(x)
# Out:
# 1234

# %%
N = int(input("n:"))
F=1

if N<0:
    print("Tanımsızdır")
elif N==0:
    print("F = ",F)
else:
    I=1
    while I<=N:
        F=F*I
        I+=1
        print("F = ",F)
# Out:
# n: 5
# F =  1
# F =  2
# F =  6
# F =  24
# F =  120
